# %%
import pandas as pd

# %%
aou_df = pd.read_csv("../data/meta/aou_cohort_statistics.csv")

# %%
ukb_df = pd.read_csv("../data/meta/ukb_cohort_statistics.csv")

# %%
aou_df
# Out:
#    ancestry_pred genetic_sex  sample_names
# 0            afr      Female         31581
# 1            afr        Male         23284
# 2            amr      Female         28448
# 3            amr        Male         14163
# 4            eas      Female          3510
# 5            eas        Male          2005
# 6            eur      Female         76252
# 7            eur        Male         51392
# 8            mid      Female           479
# 9            mid        Male           415
# 10           sas      Female          1649
# 11           sas        Male          1465

# %%
aou_df.loc[~(aou_df.ancestry_pred.isin(["eur", "afr"]))].groupby("genetic_sex").agg("sum")
# Out:
#              sample_names
# genetic_sex
# Female              34086
# Male                18048

# %%
ukb_df.loc[ukb_df.ethnic_background=="British"]
# Out:
#    ethnic_background genetic_sex  sample_names
# 16           British      Female        227268
# 17           British        Male        191960

# %%
ukb_df.loc[ukb_df.ethnic_background!="British"].groupby("genetic_sex").agg({"sample_names": "sum"}).sum()
# Out:
# sample_names    68070
# dtype: int64

# %%
ukb_df.loc[ukb_df.ethnic_background!="British"]
# Out:
#              ethnic_background genetic_sex  sample_names
# 0                      African      Female          1525
# 1                      African        Male          1621
# 2   Any other Asian background      Female           772
# 3   Any other Asian background        Male           937
# 4   Any other Black background      Female            74
# 5   Any other Black background        Male            40
# 6   Any other mixed background      Female           595
# 7   Any other mixed background        Male           353
# 8   Any other white background      Female          9308
# 9   Any other white background        Male          5868
# 10      Asian or Asian British      Female            23
# 11      Asian or Asian British        Male            19
# 12                 Bangladeshi      Female            67
# 13                 Bangladeshi        Male           154
# 14      Black or Black British      Female            16
# ...
